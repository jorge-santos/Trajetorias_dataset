# %% [markdown]
# <a href="https://colab.research.google.com/github/jorge-santos/Trajetorias_dataset/blob/main/docs/examples/geodeep_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GeoDeep - Object Detection & Segmentation
#
# [![image](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/opengeos/geoai/blob/main/docs/examples/geodeep_detection.ipynb)
#
# This notebook demonstrates how to use [GeoDeep](https://github.com/uav4geo/GeoDeep) integration in GeoAI for object detection and semantic segmentation on geospatial imagery.
#
# GeoDeep is a lightweight library that applies ONNX AI models to GeoTIFF rasters. Key features:
#
# - **Object Detection**: Cars, trees, birds, planes, utilities, and multi-class aerial detection
# - **Semantic Segmentation**: Buildings and roads
# - **GPU accelerated**: Automatically uses CUDA GPU if available via ONNX Runtime, falls back to CPU
# - **Georeferenced output**: Results in EPSG:4326 as GeoDataFrame, GeoJSON, or GeoTIFF masks
#
# ## Installation
#
# Uncomment the following line to install the required packages.

# %%
#%pip install -U "geoai-py[geodeep]"
# Out:
# Collecting geoai-py[geodeep]
#   Downloading geoai_py-0.37.0-py2.py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: albumentations in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (2.0.8)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (8.3.1)
# Collecting contextily (from geoai-py[geodeep])
#   Downloading contextily-1.7.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: datasets>=3.0 in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (4.0.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (1.1.3)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (1.8.0)
# Collecting jupyter-server-proxy (from geoai-py[geodeep])
#   Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl.metadata (8.8 kB)
# Collecting leafmap>=0.57.1 (from geoai-py[geodeep])
#   Downloading leafmap-0.61.1-py2.py3-none-any.whl.metadata (17 kB)
# Collecting localtileserver (from geoai-py[geodeep])
#   Downloading localtileserver-0.11.0-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: mapclassify in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (2.10.0)
# Collecting maplibre (from geoai-py[geodeep])
#   Downloading maplibre-0.3.6-py3-none-any.whl.metadata (4.2 kB)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (4.13.0.92)
# Collecting overturemaps (from geoai-py[geodeep])
#   Downloading overturemaps-0.20.0-py3-none-any.whl.metadata (5.9 kB)
# Collecting planetary-computer (from geoai-py[geodeep])
#   Downloading planetary_computer-1.0.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pyarrow in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (18.1.0)
# Collecting pystac-client (from geoai-py[geodeep])
#   Downloading pystac_client-0.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: rasterio in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (1.5.0)
# Collecting rioxarray (from geoai-py[geodeep])
#   Downloading rioxarray-0.22.0-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (0.25.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (1.6.1)
# Collecting smoothify (from geoai-py[geodeep])
#   Downloading smoothify-0.2.2-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: timm in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (1.0.26)
# Requirement already satisfied: tokenizers>=0.22.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (0.22.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (2.10.0+cpu)
# Collecting torchgeo (from geoai-py[geodeep])
#   Downloading torchgeo-0.9.0-py3-none-any.whl.metadata (19 kB)
# Collecting torchinfo (from geoai-py[geodeep])
#   Downloading torchinfo-1.8.0-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (4.67.3)
# Requirement already satisfied: transformers>=4.57.1 in /usr/local/lib/python3.12/dist-packages (from geoai-py[geodeep]) (5.0.0)
# Collecting geodeep (from geoai-py[geodeep])
#   Downloading geodeep-0.9.12-py3-none-any.whl.metadata (51 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.0/52.0 kB 4.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (3.25.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (2.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.12/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets>=3.0->geoai-py[geodeep]) (2025.3.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from datasets>=3.0->geoai-py[geodeep]) (6.0.3)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py[geodeep]) (1.4.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py[geodeep]) (0.28.1)
# Requirement already satisfied: typer in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py[geodeep]) (0.24.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub->geoai-py[geodeep]) (4.15.0)
# Requirement already satisfied: anywidget in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.9.21)
# Requirement already satisfied: bqplot in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.12.45)
# Collecting duckdb>=1.4.1 (from leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading duckdb-1.5.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: folium in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.20.0)
# Requirement already satisfied: gdown in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (5.2.1)
# Collecting geojson (from leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading geojson-3.2.0-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: ipyevents in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (2.0.4)
# Requirement already satisfied: ipyfilechooser in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.6.0)
# Requirement already satisfied: ipyleaflet in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.20.0)
# Collecting ipyvue<1.12.0 (from leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading ipyvue-1.11.3-py2.py3-none-any.whl.metadata (987 bytes)
# Collecting ipyvuetify (from leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl.metadata (7.5 kB)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (7.7.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (3.10.0)
# Requirement already satisfied: plotly in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (5.24.1)
# Requirement already satisfied: python-box in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (7.4.1)
# Requirement already satisfied: scooby in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (0.11.0)
# Collecting whiteboxgui (from leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: xyzservices in /usr/local/lib/python3.12/dist-packages (from leafmap>=0.57.1->geoai-py[geodeep]) (2026.3.0)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py[geodeep]) (2025.11.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py[geodeep]) (0.24.0)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.57.1->geoai-py[geodeep]) (0.7.0)
# Requirement already satisfied: scipy>=1.10.0 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py[geodeep]) (1.16.3)
# Requirement already satisfied: pydantic>=2.9.2 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py[geodeep]) (2.12.3)
# Requirement already satisfied: albucore==0.0.24 in /usr/local/lib/python3.12/dist-packages (from albumentations->geoai-py[geodeep]) (0.0.24)
# Requirement already satisfied: stringzilla>=3.10.4 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py[geodeep]) (4.6.0)
# Requirement already satisfied: simsimd>=5.9.2 in /usr/local/lib/python3.12/dist-packages (from albucore==0.0.24->albumentations->geoai-py[geodeep]) (6.5.16)
# Requirement already satisfied: geopy in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py[geodeep]) (2.4.1)
# Collecting mercantile (from contextily->geoai-py[geodeep])
#   Downloading mercantile-1.2.1-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py[geodeep]) (11.3.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from contextily->geoai-py[geodeep]) (1.5.3)
# Collecting onnxruntime>=1.10.0 (from geodeep->geoai-py[geodeep])
#   Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.2 kB)
# Requirement already satisfied: affine in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py[geodeep]) (2.4.0)
# Requirement already satisfied: attrs in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py[geodeep]) (26.1.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py[geodeep]) (2026.2.25)
# Requirement already satisfied: cligj>=0.5 in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py[geodeep]) (0.7.2)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from rasterio->geoai-py[geodeep]) (3.3.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py[geodeep]) (0.12.1)
# Requirement already satisfied: pyproj>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py[geodeep]) (3.7.2)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from geopandas->geoai-py[geodeep]) (2.1.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py[geodeep]) (3.13.4)
# Requirement already satisfied: jupyter-server>=1.24.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py[geodeep]) (2.14.0)
# Collecting simpervisor>=1.0.0 (from jupyter-server-proxy->geoai-py[geodeep])
#   Downloading simpervisor-1.0.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: tornado>=6.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py[geodeep]) (6.5.1)
# Requirement already satisfied: traitlets>=5.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server-proxy->geoai-py[geodeep]) (5.7.1)
# Requirement already satisfied: flask<4,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py[geodeep]) (3.1.3)
# Collecting Flask-Caching (from localtileserver->geoai-py[geodeep])
#   Downloading Flask_Caching-2.3.1-py3-none-any.whl.metadata (2.2 kB)
# Collecting flask-cors (from localtileserver->geoai-py[geodeep])
#   Downloading flask_cors-6.0.2-py3-none-any.whl.metadata (5.3 kB)
# Collecting flask-restx>=1.3.0 (from localtileserver->geoai-py[geodeep])
#   Downloading flask_restx-1.3.2-py2.py3-none-any.whl.metadata (9.3 kB)
# Collecting rio-tiler (from localtileserver->geoai-py[geodeep])
#   Downloading rio_tiler-9.0.5-py3-none-any.whl.metadata (11 kB)
# Collecting rio-cogeo (from localtileserver->geoai-py[geodeep])
#   Downloading rio_cogeo-7.0.2-py3-none-any.whl.metadata (6.1 kB)
# Collecting server-thread (from localtileserver->geoai-py[geodeep])
#   Downloading server_thread-0.3.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: werkzeug in /usr/local/lib/python3.12/dist-packages (from localtileserver->geoai-py[geodeep]) (3.1.7)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.12/dist-packages (from mapclassify->geoai-py[geodeep]) (3.6.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from scikit-learn->geoai-py[geodeep]) (3.6.0)
# Requirement already satisfied: branca in /usr/local/lib/python3.12/dist-packages (from maplibre->geoai-py[geodeep]) (0.8.2)
# Collecting eval-type-backport (from maplibre->geoai-py[geodeep])
#   Downloading eval_type_backport-0.3.1-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: jinja2>=3.1.6 in /usr/local/lib/python3.12/dist-packages (from maplibre->geoai-py[geodeep]) (3.1.6)
# Requirement already satisfied: orjson>=3.9.0 in /usr/local/lib/python3.12/dist-packages (from overturemaps->geoai-py[geodeep]) (3.11.8)
# Collecting pystac>=1.0.0 (from planetary-computer->geoai-py[geodeep])
#   Downloading pystac-1.14.3-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: pytz>=2020.5 in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py[geodeep]) (2025.2)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.12/dist-packages (from planetary-computer->geoai-py[geodeep]) (1.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pystac-client->geoai-py[geodeep]) (2.9.0.post0)
# Collecting xarray>=2026.2 (from rioxarray->geoai-py[geodeep])
#   Downloading xarray-2026.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: imageio!=2.35.0,>=2.33 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py[geodeep]) (2.37.3)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py[geodeep]) (2026.3.3)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.12/dist-packages (from scikit-image->geoai-py[geodeep]) (0.5)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.12/dist-packages (from timm->geoai-py[geodeep]) (0.25.0+cpu)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py[geodeep]) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->geoai-py[geodeep]) (1.14.0)
# Requirement already satisfied: einops>=0.3 in /usr/local/lib/python3.12/dist-packages (from torchgeo->geoai-py[geodeep]) (0.8.2)
# Collecting jsonargparse>=4.35 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py[geodeep])
#   Downloading jsonargparse-4.47.0-py3-none-any.whl.metadata (12 kB)
# Collecting kornia>=0.8.2 (from torchgeo->geoai-py[geodeep])
#   Downloading kornia-0.8.2-py2.py3-none-any.whl.metadata (18 kB)
# Collecting lightly!=1.4.26,>=1.4.5 (from torchgeo->geoai-py[geodeep])
#   Downloading lightly-1.5.23-py3-none-any.whl.metadata (40 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 40.3/40.3 kB 3.3 MB/s eta 0:00:00
# Collecting lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2 (from torchgeo->geoai-py[geodeep])
#   Downloading lightning-2.6.1-py3-none-any.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.8/44.8 kB 4.1 MB/s eta 0:00:00
# Collecting segmentation-models-pytorch>=0.5 (from torchgeo->geoai-py[geodeep])
#   Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl.metadata (17 kB)
# Collecting torchmetrics>=1.2 (from torchgeo->geoai-py[geodeep])
#   Downloading torchmetrics-1.9.0-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: blinker>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->geoai-py[geodeep]) (1.9.0)
# Requirement already satisfied: itsdangerous>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->geoai-py[geodeep]) (2.2.0)
# Requirement already satisfied: markupsafe>=2.1.1 in /usr/local/lib/python3.12/dist-packages (from flask<4,>=2.0.0->localtileserver->geoai-py[geodeep]) (3.0.3)
# Collecting aniso8601>=0.82 (from flask-restx>=1.3.0->localtileserver->geoai-py[geodeep])
#   Downloading aniso8601-10.0.1-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->geoai-py[geodeep]) (4.26.0)
# Requirement already satisfied: referencing in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->geoai-py[geodeep]) (0.37.0)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.12/dist-packages (from flask-restx>=1.3.0->localtileserver->geoai-py[geodeep]) (6.5.2)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->jupyter-server-proxy->geoai-py[geodeep]) (1.23.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->geoai-py[geodeep]) (4.13.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->geoai-py[geodeep]) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface_hub->geoai-py[geodeep]) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface_hub->geoai-py[geodeep]) (0.16.0)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (6.17.1)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (3.6.10)
# Requirement already satisfied: ipython>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (7.34.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (3.0.16)
# Requirement already satisfied: docstring-parser>=0.17 in /usr/local/lib/python3.12/dist-packages (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py[geodeep]) (0.17.0)
# Collecting typeshed-client>=2.8.2 (from jsonargparse[signatures]>=4.35->torchgeo->geoai-py[geodeep])
#   Downloading typeshed_client-2.9.0-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (25.1.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (5.9.1)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.5.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (7.17.0)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.24.1)
# Requirement already satisfied: pyzmq>=24 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (26.2.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.9.0)
# Collecting kornia_rs>=0.1.9 (from kornia>=0.8.2->torchgeo->geoai-py[geodeep])
#   Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting hydra-core>=1.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep])
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting lightly_utils~=0.0.0 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep])
#   Downloading lightly_utils-0.0.2-py3-none-any.whl.metadata (1.4 kB)
# Requirement already satisfied: six>=1.10 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep]) (1.17.0)
# Collecting pytorch_lightning>=1.0.4 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep])
#   Downloading pytorch_lightning-2.6.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: urllib3>=1.25.3 in /usr/local/lib/python3.12/dist-packages (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep]) (2.5.0)
# Collecting aenum>=3.1.11 (from lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep])
#   Downloading aenum-3.1.17-py3-none-any.whl.metadata (3.8 kB)
# Collecting lightning-utilities<2.0,>=0.10.0 (from lightning!=2.3.*,!=2.5.0,!=2.5.5,!=2.5.6,>=2->torchgeo->geoai-py[geodeep])
#   Downloading lightning_utilities-0.15.3-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py[geodeep]) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py[geodeep]) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py[geodeep]) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->leafmap>=0.57.1->geoai-py[geodeep]) (1.5.0)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.10.0->geodeep->geoai-py[geodeep]) (25.12.19)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.12/dist-packages (from onnxruntime>=1.10.0->geodeep->geoai-py[geodeep]) (5.29.6)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas->datasets>=3.0->geoai-py[geodeep]) (2025.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py[geodeep]) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py[geodeep]) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic>=2.9.2->albumentations->geoai-py[geodeep]) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.32.2->datasets>=3.0->geoai-py[geodeep]) (3.4.6)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->geoai-py[geodeep]) (1.3.0)
# Requirement already satisfied: psygnal>=0.8.1 in /usr/local/lib/python3.12/dist-packages (from anywidget->leafmap>=0.57.1->geoai-py[geodeep]) (0.15.1)
# Requirement already satisfied: traittypes>=0.0.6 in /usr/local/lib/python3.12/dist-packages (from bqplot->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.3)
# Collecting cachelib>=0.9.0 (from Flask-Caching->localtileserver->geoai-py[geodeep])
#   Downloading cachelib-0.13.0-py3-none-any.whl.metadata (2.0 kB)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from gdown->leafmap>=0.57.1->geoai-py[geodeep]) (4.13.5)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.12/dist-packages (from geopy->contextily->geoai-py[geodeep]) (2.1)
# Requirement already satisfied: jupyter-leaflet<0.21,>=0.20 in /usr/local/lib/python3.12/dist-packages (from ipyleaflet->leafmap>=0.57.1->geoai-py[geodeep]) (0.20.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from plotly->leafmap>=0.57.1->geoai-py[geodeep]) (9.1.4)
# Collecting morecantile<8.0,>=5.0 (from rio-cogeo->localtileserver->geoai-py[geodeep])
#   Downloading morecantile-7.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: cachetools in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py[geodeep]) (6.2.6)
# Collecting color-operations (from rio-tiler->localtileserver->geoai-py[geodeep])
#   Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: numexpr in /usr/local/lib/python3.12/dist-packages (from rio-tiler->localtileserver->geoai-py[geodeep]) (2.14.1)
# Requirement already satisfied: uvicorn in /usr/local/lib/python3.12/dist-packages (from server-thread->localtileserver->geoai-py[geodeep]) (0.42.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->geoai-py[geodeep]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->geoai-py[geodeep]) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer->huggingface_hub->geoai-py[geodeep]) (0.0.4)
# Requirement already satisfied: ipytree in /usr/local/lib/python3.12/dist-packages (from whiteboxgui->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.2)
# Collecting whitebox (from whiteboxgui->leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading whitebox-2.3.6-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (25.1.0)
# Requirement already satisfied: omegaconf<2.4,>=2.2 in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep]) (2.3.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.12/dist-packages (from hydra-core>=1.0.0->lightly!=1.4.26,>=1.4.5->torchgeo->geoai-py[geodeep]) (4.9.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (1.8.15)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel>=4.5.1->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (5.9.5)
# Collecting jedi>=0.16 (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep])
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->geoai-py[geodeep]) (2025.9.1)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema->flask-restx>=1.3.0->localtileserver->geoai-py[geodeep]) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=7.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (4.9.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (4.1.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.1.1)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (3.2.0)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (2.21.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer->huggingface_hub->geoai-py[geodeep]) (4.0.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.7.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.12/dist-packages (from widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (6.5.7)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->gdown->leafmap>=0.57.1->geoai-py[geodeep]) (2.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.12/dist-packages (from requests[socks]->gdown->leafmap>=0.57.1->geoai-py[geodeep]) (1.7.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.8.6)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (25.10.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->huggingface_hub->geoai-py[geodeep]) (0.1.2)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.12/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (1.3.3)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=4.0.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.6.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (3.0)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.12/dist-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->leafmap>=0.57.1->geoai-py[geodeep]) (0.2.4)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.24.0->jupyter-server-proxy->geoai-py[geodeep]) (1.4.0)
# Downloading leafmap-0.61.1-py2.py3-none-any.whl (666 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 666.8/666.8 kB 39.7 MB/s eta 0:00:00
# Downloading contextily-1.7.0-py3-none-any.whl (16 kB)
# Downloading geoai_py-0.37.0-py2.py3-none-any.whl (599 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 599.7/599.7 kB 32.5 MB/s eta 0:00:00
# Downloading geodeep-0.9.12-py3-none-any.whl (47 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.0/48.0 kB 4.0 MB/s eta 0:00:00
# Downloading jupyter_server_proxy-4.5.0-py3-none-any.whl (45 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 3.8 MB/s eta 0:00:00
# Downloading localtileserver-0.11.0-py3-none-any.whl (30 kB)
# Downloading maplibre-0.3.6-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 70.0 MB/s eta 0:00:00
# Downloading overturemaps-0.20.0-py3-none-any.whl (23 kB)
# Downloading planetary_computer-1.0.0-py3-none-any.whl (14 kB)
# Downloading pystac_client-0.9.0-py3-none-any.whl (41 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.8/41.8 kB 3.4 MB/s eta 0:00:00
# Downloading rioxarray-0.22.0-py3-none-any.whl (72 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 6.7 MB/s eta 0:00:00
# Downloading smoothify-0.2.2-py3-none-any.whl (16 kB)
# Downloading torchgeo-0.9.0-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.1/688.1 kB 50.8 MB/s eta 0:00:00
# Downloading torchinfo-1.8.0-py3-none-any.whl (23 kB)
# Downloading duckdb-1.5.1-cp312-cp312-manylinux_2_26_x86_64.manylinux_2_28_x86_64.whl (21.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.4/21.4 MB 72.9 MB/s eta 0:00:00
# Downloading flask_restx-1.3.2-py2.py3-none-any.whl (2.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 96.6 MB/s eta 0:00:00
# Downloading ipyvue-1.11.3-py2.py3-none-any.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 100.0 MB/s eta 0:00:00
# Downloading jsonargparse-4.47.0-py3-none-any.whl (129 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.1/129.1 kB 11.8 MB/s eta 0:00:00
# Downloading kornia-0.8.2-py2.py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 62.4 MB/s eta 0:00:00
# Downloading lightly-1.5.23-py3-none-any.whl (863 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 863.6/863.6 kB 52.5 MB/s eta 0:00:00
# Downloading lightning-2.6.1-py3-none-any.whl (853 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 853.6/853.6 kB 55.6 MB/s eta 0:00:00
# Downloading onnxruntime-1.24.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (17.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 84.3 MB/s eta 0:00:00
# Downloading pystac-1.14.3-py3-none-any.whl (208 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.5/208.5 kB 20.7 MB/s eta 0:00:00
# Downloading segmentation_models_pytorch-0.5.0-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.8/154.8 kB 10.8 MB/s eta 0:00:00
# Downloading simpervisor-1.0.0-py3-none-any.whl (8.3 kB)
# Downloading torchmetrics-1.9.0-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 983.4/983.4 kB 58.9 MB/s eta 0:00:00
# Downloading xarray-2026.2.0-py3-none-any.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 72.2 MB/s eta 0:00:00
# Downloading eval_type_backport-0.3.1-py3-none-any.whl (6.1 kB)
# Downloading Flask_Caching-2.3.1-py3-none-any.whl (28 kB)
# Downloading flask_cors-6.0.2-py3-none-any.whl (13 kB)
# Downloading geojson-3.2.0-py3-none-any.whl (15 kB)
# Downloading ipyvuetify-1.11.3-py2.py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 82.8 MB/s eta 0:00:00
# Downloading mercantile-1.2.1-py3-none-any.whl (14 kB)
# Downloading rio_cogeo-7.0.2-py3-none-any.whl (21 kB)
# Downloading rio_tiler-9.0.5-py3-none-any.whl (287 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.5/287.5 kB 21.1 MB/s eta 0:00:00
# Downloading server_thread-0.3.0-py3-none-any.whl (6.6 kB)
# Downloading whiteboxgui-2.3.0-py2.py3-none-any.whl (108 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.6/108.6 kB 9.6 MB/s eta 0:00:00
# Downloading aenum-3.1.17-py3-none-any.whl (165 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 165.6/165.6 kB 16.3 MB/s eta 0:00:00
# Downloading aniso8601-10.0.1-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 5.2 MB/s eta 0:00:00
# Downloading cachelib-0.13.0-py3-none-any.whl (20 kB)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 14.3 MB/s eta 0:00:00
# Downloading kornia_rs-0.1.10-cp312-cp312-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 84.9 MB/s eta 0:00:00
# Downloading lightly_utils-0.0.2-py3-none-any.whl (6.4 kB)
# Downloading lightning_utilities-0.15.3-py3-none-any.whl (31 kB)
# Downloading morecantile-7.0.3-py3-none-any.whl (50 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.2 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.6.1-py3-none-any.whl (857 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 857.3/857.3 kB 54.0 MB/s eta 0:00:00
# Downloading typeshed_client-2.9.0-py3-none-any.whl (786 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 786.5/786.5 kB 38.0 MB/s eta 0:00:00
# Downloading color_operations-0.2.0-cp312-cp312-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (204 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.3/204.3 kB 16.7 MB/s eta 0:00:00
# Downloading whitebox-2.3.6-py2.py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.0/74.0 kB 5.2 MB/s eta 0:00:00
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 51.2 MB/s eta 0:00:00
# Installing collected packages: aniso8601, aenum, whitebox, typeshed-client, torchinfo, simpervisor, mercantile, lightning-utilities, lightly_utils, kornia_rs, jsonargparse, jedi, geojson, eval-type-backport, duckdb, color-operations, cachelib, server-thread, pystac, overturemaps, onnxruntime, hydra-core, xarray, torchmetrics, morecantile, maplibre, kornia, geodeep, flask-cors, Flask-Caching, contextily, smoothify, rioxarray, rio-tiler, rio-cogeo, pytorch_lightning, flask-restx, pystac-client, localtileserver, lightning, lightly, segmentation-models-pytorch, planetary-computer, torchgeo, jupyter-server-proxy, ipyvue, whiteboxgui, ipyvuetify, leafmap, geoai-py
#   Attempting uninstall: duckdb
#     Found existing installation: duckdb 1.3.2
#     Uninstalling duckdb-1.3.2:
#       Successfully uninstalled duckdb-1.3.2
#   Attempting uninstall: xarray
#     Found existing installation: xarray 2025.12.0
#     Uninstalling xarray-2025.12.0:
#       Successfully uninstalled xarray-2025.12.0
# Successfully installed Flask-Caching-2.3.1 aenum-3.1.17 aniso8601-10.0.1 cachelib-0.13.0 color-operations-0.2.0 contextily-1.7.0 duckdb-1.5.1 eval-type-backport-0.3.1 flask-cors-6.0.2 flask-restx-1.3.2 geoai-py-0.37.0 geodeep-0.9.12 geojson-3.2.0 hydra-core-1.3.2 ipyvue-1.11.3 ipyvuetify-1.11.3 jedi-0.19.2 jsonargparse-4.47.0 jupyter-server-proxy-4.5.0 kornia-0.8.2 kornia_rs-0.1.10 leafmap-0.61.1 lightly-1.5.23 lightly_utils-0.0.2 lightning-2.6.1 lightning-utilities-0.15.3 localtileserver-0.11.0 maplibre-0.3.6 mercantile-1.2.1 morecantile-7.0.3 onnxruntime-1.24.4 overturemaps-0.20.0 planetary-computer-1.0.0 pystac-1.14.3 pystac-client-0.9.0 pytorch_lightning-2.6.1 rio-cogeo-7.0.2 rio-tiler-9.0.5 rioxarray-0.22.0 segmentation-models-pytorch-0.5.0 server-thread-0.3.0 simpervisor-1.0.0 smoothify-0.2.2 torchgeo-0.9.0 torchinfo-1.8.0 torchmetrics-1.9.0 typeshed-client-2.9.0 whitebox-2.3.6 whiteboxgui-2.3.0 xarray-2026.2.0

# %%
import geoai

device = geoai.get_device()
print(f"Using device: {device}")
# Out:
# Using device: cpu

# %% [markdown]
# ## List Available Models
#
# GeoDeep includes 9 built-in models for detection and segmentation tasks. Models are automatically downloaded and cached on first use.

# %%
from geoai import list_geodeep_models, GEODEEP_MODELS

for name, desc in list_geodeep_models().items():
    model_type = GEODEEP_MODELS[name]["type"]
    print(f"  {name:15s} [{model_type:13s}] {desc}")
# Out:
#   cars            [detection    ] Car detection using YOLOv7-m (10 cm/px)
#   trees           [detection    ] Tree crown detection using RetinaNet (10 cm/px)
#   trees_yolov9    [detection    ] Tree crown detection using YOLOv9 (10 cm/px)
#   birds           [detection    ] Bird detection using RetinaNet (2 cm/px)
#   planes          [detection    ] Plane detection using YOLOv7-tiny (70 cm/px)
#   aerovision      [detection    ] Multi-class aerial detection using YOLOv8 (30 cm/px)
#   utilities       [detection    ] Utility infrastructure detection using YOLOv8 (3 cm/px)
#   buildings       [segmentation ] Building segmentation using XUNet (50 cm/px)
#   roads           [segmentation ] Road segmentation (21 cm/px)

# %% [markdown]
# ## Download Sample Data
#
# Download a high-resolution aerial image for testing. Replace the URL below with your own GeoTIFF if desired.

# %%
url = "https://data.source.coop/opengeos/geoai/cars-7cm.tif"
image_path = geoai.download_file(url)
# Out:
# Downloading cars-7cm.tif: 100%|██████████| 92.0M/92.0M [00:03<00:00, 30.1MB/s]

# %% [markdown]
# ## Visualize the Input Image

# %%
geoai.view_raster(url)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8f8440bc8e5fc7a6dbda7eddc01cb9b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/proj4@2.8.1/dist/proj4.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster@1.6.0&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/georaster-layer-for-leaflet@4.1.2/dist/georaster-layer-for-leaflet.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8f8440bc8e5fc7a6dbda7eddc01cb9b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8f8440bc8e5fc7a6dbda7eddc01cb9b4 = L.map(
#                 &quot;map_8f8440bc8e5fc7a6dbda7eddc01cb9b4&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_8f8440bc8e5fc7a6dbda7eddc01cb9b4);
#
#
#
#
#
#             var tile_layer_196a1d9565f1b72d4a885f85e5e71b1d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_196a1d9565f1b72d4a885f85e5e71b1d.addTo(map_8f8440bc8e5fc7a6dbda7eddc01cb9b4);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_8f8440bc8e5fc7a6dbda7eddc01cb9b4);
#
#
#             map_8f8440bc8e5fc7a6dbda7eddc01cb9b4.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var macro_element_ae74142d5b594f2afdd0538afa584d54 = L.layerGroup();
#
#             (function() {
#                 var layerName = &quot;Raster&quot;;
#                 if (true) {
#                     macro_element_ae74142d5b594f2afdd0538afa584d54._layerControlName = layerName;
#                     map_8f8440bc8e5fc7a6dbda7eddc01cb9b4.layerControlEntries = map_8f8440bc8e5fc7a6dbda7eddc01cb9b4.layerControlEntries || [];
#                     map_8f8440bc8e5fc7a6dbda7eddc01cb9b4.layerControlEntries.push({ layer: macro_element_ae74142d5b594f2afdd0538afa584d54, name: layerName });
#                 }
#             })();
#
#             (async function() {
#                 const waitForGeoRaster = (maxAttempts = 60, delay = 200) =&gt;
#                     new Promise((resolve, reject) =&gt; {
#                         let attempts = 0;
#                         const check = () =&gt; {
#                             if (window.parseGeoraster &amp;&amp; window.GeoRasterLayer) {
#                                 resolve();
#                             } else if (attempts &gt;= maxAttempts) {
#                                 reject(new Error(&quot;GeoRaster libraries failed to load&quot;));
#                             } else {
#                                 attempts += 1;
#                                 setTimeout(check, delay);
#                             }
#                         };
#                         check();
#                     });
#
#                 try {
#                     await waitForGeoRaster();
#                     const mapRef = map_8f8440bc8e5fc7a6dbda7eddc01cb9b4;
#                     const layerSequence = 1;
#
#                     // Create a custom pane for this GeoTIFF layer with explicit z-index
#                     const paneName = &#x27;geotiff-pane-&#x27; + layerSequence;
#                     if (!mapRef.getPane(paneName)) {
#                         const pane = mapRef.createPane(paneName);
#                         // Set z-index: 400 is default for overlays (vectors), use 300-399 range
#                         // for GeoTIFF layers so they appear below vector layers
#                         pane.style.zIndex = 300 + layerSequence;
#                     }
#
#                     const indexes = null;
#                     const georaster = await window.parseGeoraster(&quot;https://data.source.coop/opengeos/geoai/cars-7cm.tif&quot;);
#                     const palette = [];
#                     const hasPalette = Array.isArray(palette) &amp;&amp; palette.length &gt; 0;
#                     const nodataColor = null;
#                     const suppliedRange = null;
#                     const layerOptions = {&quot;name&quot;: &quot;Raster&quot;, &quot;opacity&quot;: 1.0, &quot;resolution&quot;: 128, &quot;zIndex&quot;: 501};
#                     layerOptions.georaster = georaster;

# %% [markdown]
# ## Object Detection
#
# ### Car Detection
#
# Use the `GeoDeep` class to detect cars in the aerial image. The result is a GeoDataFrame with bounding box polygons, confidence scores, and class labels.

# %%
from geoai import GeoDeep

gd = GeoDeep("cars")
print(gd)
# Out:
# GeoDeep[cars] (detection, cpu) - Car detection using YOLOv7-m (10 cm/px)

# %%
detections = gd.detect(image_path)
print(f"Found {len(detections)} cars")
detections.head()
# Out:
# Found 1050 cars
#       score class                                           geometry
# 0  0.940986   car  POLYGON ((-95.42226 29.67986, -95.42219 29.679...
# 1  0.873142   car  POLYGON ((-95.42241 29.6796, -95.42236 29.6796...
# 2  0.900805   car  POLYGON ((-95.41966 29.6801, -95.41962 29.6801...
# 3  0.983273   car  POLYGON ((-95.42094 29.67897, -95.4209 29.6789...
# 4  0.975856   car  POLYGON ((-95.42343 29.67845, -95.42338 29.678...

# %% [markdown]
# ### Visualize Detections
#
# Overlay detection results on the original image.

# %%
geoai.view_vector_interactive(detections, tiles=image_path)
# Out:
# <iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_492eeace8a6ce6c71d9a24e7822e4616 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.min.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet.fullscreen@3.0.0/Control.FullScreen.css&quot;/&gt;
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_492eeace8a6ce6c71d9a24e7822e4616&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_492eeace8a6ce6c71d9a24e7822e4616 = L.map(
#                 &quot;map_492eeace8a6ce6c71d9a24e7822e4616&quot;,
#                 {
#                     center: [20.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 2,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
#   &quot;drawExport&quot;: false,
#   &quot;layersControl&quot;: true,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_492eeace8a6ce6c71d9a24e7822e4616);
#
#
#
#
#
#             var tile_layer_4866d459a7b4203e8a60a3a530b626b9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 24,
#   &quot;maxNativeZoom&quot;: 24,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4866d459a7b4203e8a60a3a530b626b9.addTo(map_492eeace8a6ce6c71d9a24e7822e4616);
#
#
#             L.control.fullscreen(
#                 {
#   &quot;position&quot;: &quot;topleft&quot;,
#   &quot;title&quot;: &quot;Full Screen&quot;,
#   &quot;titleCancel&quot;: &quot;Exit Full Screen&quot;,
#   &quot;forceSeparateButton&quot;: false,
# }
#             ).addTo(map_492eeace8a6ce6c71d9a24e7822e4616);
#
#
#             map_492eeace8a6ce6c71d9a24e7822e4616.fitBounds(
#                 [[20, 0], [20, 0]],
#                 {&quot;maxZoom&quot;: 2}
#             );
#
#
#             var tile_layer_51f82ff927f9aa1b7168d586866f2fae = L.tileLayer(
#                 &quot;http://localhost:40269/api/tiles/{z}/{x}/{y}.png?\u0026filename=%2Fcontent%2Fcars-7cm.tif&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 30,
#   &quot;maxNativeZoom&quot;: 30,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;localtileserver&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1.0,
# }
#
#             );
#
#
#             tile_layer_51f82ff927f9aa1b7168d586866f2fae.addTo(map_492eeace8a6ce6c71d9a24e7822e4616);
#
#
#         function geo_json_4ebaa101e3fb56118fdcc97591e63752_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0, &quot;opacity&quot;: 0.7, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_4ebaa101e3fb56118fdcc97591e63752_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0, &quot;weight&quot;: 4};
#             }
#         }
#
#         function geo_json_4ebaa101e3fb56118fdcc97591e63752_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_4ebaa101e3fb56118fdcc97591e63752.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_4ebaa101e3fb56118fdcc97591e63752_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_4ebaa101e3fb56118fdcc97591e63752 = L.geoJson(null, {
#                 onEachFeature: geo_json_4ebaa101e3fb56118fdcc97591e63752_onEachFeature,
#
#                 style: geo_json_4ebaa101e3fb56118fdcc97591e63752_styler,
#             ...{
#   &quot;maxZoom&quot;: 30,
# }
#         });
#
#         function geo_json_4ebaa101e3fb56118fdcc97591e63752_add (data) {
#             geo_json_4ebaa101e3fb56118fdcc97591e63752
#                 .addData(data);
#         }
#             geo_json_4ebaa101e3fb56118fdcc97591e63752_add({&quot;bbox&quot;: [-95.42489966471081, 29.67779970871236, -95.41930033528921, 29.680399708719857], &quot;features&quot;: [{&quot;bbox&quot;: [-95.42225825649624, 29.6798060780

# %% [markdown]
# ### Save Detection Results
#
# Export detections to GeoJSON, GeoPackage, or Shapefile.

# %%
gd.detect(image_path, output_path="car_detections.geojson")

# %% [markdown]
# ### Detection with Confidence Filtering
#
# Use a higher confidence threshold to reduce false positives.

# %%
gd_strict = GeoDeep("cars", conf_threshold=0.7)
high_conf = gd_strict.detect(image_path)
print(f"High-confidence detections: {len(high_conf)}")
high_conf.head()

# %% [markdown]
# ### Tree Detection

# %%
url = "https://data.source.coop/opengeos/geoai/uc-berkeley.tif"
image_path = geoai.download_file(url)
# Out:
# Downloading uc-berkeley.tif: 100%|██████████| 12.1M/12.1M [00:00<00:00, 17.6MB/s]

# %%
gd_trees = GeoDeep("trees")
trees = gd_trees.detect(image_path)
print(f"Found {len(trees)} trees")
trees.head()

# %%
geoai.view_vector_interactive(trees, tiles=image_path)

# %% [markdown]
# ### Model Properties
#
# Access model metadata via OOP properties.

# %%
gd_aero = GeoDeep("aerovision")
print(f"Model type:  {gd_aero.model_type}")
print(f"Classes:     {gd_aero.available_classes}")
print(f"Description: {gd_aero.model_info['description']}")
print(f"Resolution:  {gd_aero.model_info['resolution']}")

# %% [markdown]
# ## Semantic Segmentation
#
# ### Building Segmentation
#
# Segment buildings and save the result as a GeoTIFF mask.

# %%
gd_buildings = GeoDeep("buildings")
print(gd_buildings)
print(f"Classes: {gd_buildings.available_classes}")

# %%
result = gd_buildings.segment(
    image_path,
    output_raster_path="buildings_mask.tif",
)
print(f"Mask shape: {result['mask'].shape}")
print(f"Unique values: {set(result['mask'].flatten())}")

# %% [markdown]
# ### Segmentation to Vector
#
# Export segmentation as vector polygons (GeoPackage).

# %%
result = gd_buildings.segment(
    image_path,
    output_vector_path="buildings.gpkg",
)
buildings_gdf = result["gdf"]
print(f"Found {len(buildings_gdf)} building polygons")
buildings_gdf.head()

# %%
geoai.view_vector_interactive(buildings_gdf, tiles=image_path)

# %% [markdown]
# ### Road Segmentation

# %%
gd_roads = GeoDeep("roads")
road_result = gd_roads.segment(
    image_path,
    output_raster_path="roads_mask.tif",
    output_vector_path="roads.gpkg",
)
roads_gdf = road_result["gdf"]
print(f"Road mask shape: {road_result['mask'].shape}")
print(f"Found {len(roads_gdf)} road polygons")

# %%
geoai.view_vector_interactive(roads_gdf, tiles=url)

# %% [markdown]
# ## Convenience Functions
#
# For one-off calls, use module-level convenience functions without creating a class instance.

# %%
from geoai import geodeep_detect, geodeep_segment

# One-liner detection
plane_detections = geodeep_detect(image_path, model_id="planes")
print(f"Planes found: {len(plane_detections)}")

# One-liner segmentation
seg_result = geodeep_segment(
    image_path,
    model_id="buildings",
    output_raster_path="quick_buildings.tif",
)
print(f"Segmentation mask shape: {seg_result['mask'].shape}")

# %% [markdown]
# ## Batch Processing
#
# Process multiple images at once. Results are combined into a single GeoDataFrame with a `source_file` column.

# %%
# Example with a list of images (using the same image twice for demo)
image_list = [image_path, image_path]

gd_batch = GeoDeep("cars")
batch_results = gd_batch.detect_batch(image_list, output_dir="batch_results/")
print(f"Total detections across all images: {len(batch_results)}")
batch_results[["class", "score", "source_file"]].head()
